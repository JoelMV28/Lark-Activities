# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the data set into python

# %%
data=pd.read_excel("Dataset_w6.xlsx")
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %% [markdown]
# # 1. Find out how many countries are there in the dataset.

# %%
print("Number of countries=",(data["country"].count()))
# Out:
# Number of countries= 196

# %% [markdown]
# # 2. Examine the data by using visualizations.

# %%
# 1.Pairplot
sns.pairplot(data)

# %%
#2.Boxplot
plt.figure(figsize=(12,10))
sns.boxplot(x="Region",y="GDP per capita (current US$)",data=data)
plt.title(" Region Vs GDP per capita (current US$) )",fontsize=16,weight="bold")
plt.xlabel("Region",fontsize="12")
plt.ylabel("GDP per capita (current US$)",fontsize="12")
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#3.Barplot
plt.figure(figsize=(10,6))
sns.barplot(x="Region",y="Population in thousands (2017)",data=data)
plt.title("Region Vs Population(2017)",fontsize=16,weight="bold")
plt.xticks(rotation=90)
plt.show()

# %%
#4.Heatmap
slice_data=data[["Surface area (km2)","Population in thousands (2017)","GDP per capita (current US$)","International trade: Imports (million US$)"]]
sns.heatmap(slice_data.corr(),annot=True)
plt.title("Heatmap",fontsize=16,weight="bold")
plt.xticks(Rotation=90)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_3704/919283601.py:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.xticks(Rotation=90)
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'Surface area (km2)'),
#   Text(1.5, 0, 'Population in thousands (2017)'),
#   Text(2.5, 0, 'GDP per capita (current US$)'),
#   Text(3.5, 0, 'International trade: Imports (million US$)')])

# %% [markdown]
# # 3. Find out how many countries with respect to the region are available

# %%
data.groupby("Region")[["country"]].count()
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %% [markdown]
# # 4. On average which region has the highest
# a. GDP per capita (current US$)
#
# b. International trade: Imports (million US$)

# %%
#GDP per capita (current US$)

# %%
#Finding Mean of GDP per capita (current US$)
avg1=data.groupby("Region")[["GDP per capita (current US$)"]].mean().round(2)
avg1
# Out:
#                    GDP per capita (current US$)
# Region
# Caribbean                              15135.56
# CentralAmerica                          6348.14
# CentralAsia                             4329.88
# EasternAfrica                           2088.85
# EasternAsia                            27967.61
# EasternEurope                           9292.49
# Melanesia                               9261.96
# Micronesia                              5008.30
# MiddleAfrica                            3928.83
# NorthernAfrica                          3934.96
# NorthernAmerica                        57659.00
# NorthernEurope                         42098.22
# Oceania                                44823.25
# Polynesia                               8686.52
# South-easternAsia                      10299.03
# SouthAmerica                            8499.78
# SouthernAfrica                          4191.90
# SouthernAsia                            2968.40
# ...

# %%
#Selecting the largest avearage to find the region with highest GDP per capita (current US$
highest_gdp=average1.nlargest(1,["GDP per capita (current US$)"])
highest_gdp
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                       57659.0

# %%
# International trade: Imports (million US$)

# %%
#Finding Mean of International trade: Imports (million US$)
avg2=data.groupby("Region")[["International trade: Imports (million US$)"]].mean().round(2)
avg2
# Out:
#                    International trade: Imports (million US$)
# Region
# Caribbean                                             3057.31
# CentralAmerica                                       57031.50
# CentralAsia                                          12063.40
# EasternAfrica                                         4726.18
# EasternAsia                                         451995.00
# EasternEurope                                        85243.90
# Melanesia                                             2896.40
# Micronesia                                              99.00
# MiddleAfrica                                          4381.22
# NorthernAfrica                                       35034.40
# NorthernAmerica                                     663552.25
# NorthernEurope                                      113407.20
# Oceania                                             112914.50
# Polynesia                                              432.00
# ...

# %%
#Selecting the largest avearage to find the region with highest International trade: Imports (million US$)
highest_iti=avg2.nlargest(1,["International trade: Imports (million US$)"])
highest_iti
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP per capita

# %%
#Finding standard deviation of GDP per capita (current US$),then finding the lowest among them to select the region with consistency
Gdp=data.groupby('Region')[["GDP per capita (current US$)"]].std()
Gdp_c=Gdp.nsmallest(1,"GDP per capita (current US$)")
Gdp_c
# Out:
#                GDP per capita (current US$)
# Region
# WesternAfrica                    815.095399
