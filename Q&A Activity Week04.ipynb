# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_excel("Telco-Customer-Churn.xlsx")
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # 1.Compare churn count with respect to gender.

# %%
plt.figure(figsize=(10,8))
sns.countplot(data["gender"],hue=data['Churn'])
plt.title('Comparison of Churn Count with Respect to Gender',fontsize="16",fontweight="bold")
plt.xlabel("Gender",fontsize="14")
plt.ylabel("Count",fontsize="14")
plt.grid(linestyle='--')
plt.show
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2. Find out how many female senior citizens there in the dataset

# %%
fs=data[(data['gender']=="Female")&(data['SeniorCitizen']==1)]
plt.figure(figsize=(8,8))
sns.countplot(x=fs["gender"])
plt.title("Number of Female Citizen",fontweight="bold",fontsize="16")
plt.xlabel("Gender",fontsize="14")
plt.ylabel("Count",fontsize="14")
plt.grid(linestyle="--")
plt.show
print("Number of Female Senior Citizens = ",x.count())
# Out:
# Number of Female Senior Citizens =  568

# %% [markdown]
# # 3.Compare 'tenure' with 'Total Charges'

# %%
plt.figure(figsize=(12,10))
plt.scatter(data["tenure"],data["TotalCharges"],s=8,c="brown",marker="^")
plt.title("Tenure vs Total Charges",fontsize="16",fontweight="bold")
plt.xlabel("Tenure",fontsize=14)
plt.ylabel("Total Charge",fontsize=14)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 4. Find out which contract is preferred by the senior citizen.

# %%
sc=data[(data['SeniorCitizen']==1)]
plt.figure(figsize=(8,8))
sns.countplot(x=sc['Contract'])
plt.title("Contract Prefference of Senior Citizen",fontweight="bold",fontsize="16")
plt.xlabel("Contract",fontsize="14")
plt.ylabel("Count",fontsize="14")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 5. Comment on your finds on Payment Method?

# %%
plt.figure(figsize=(10,6))
sns.countplot(data["PaymentMethod"])
plt.suptitle("1.Most Commonly used payment method is Electronic Check and the least used is Credit Card",fontsize=16)
plt.title("Payment Methods",fontweight="bold",fontsize="18")
plt.xlabel("Payment Methods",fontsize="14")
plt.ylabel("Count",fontsize="14")
plt.show

plt.figure(figsize=(10,8))
sns.countplot(data["gender"],hue=data["PaymentMethod"])
plt.suptitle("2.Most Commonly used payment method by both Females and Males is Electronic Check,\nwhereas the least used by males is Bank Transfer and that of females is Credit Card",fontsize=16)
plt.title("Payment Methods used by Males and Females",fontweight="bold",fontsize="18")
plt.xlabel("Payment Methods",fontsize="14")
plt.ylabel("Count",fontsize="14")
plt.grid(linestyle="--")
plt.show

sc=data[(data['SeniorCitizen']==1)]
plt.figure(figsize=(10,8))
sns.countplot(x=sc['PaymentMethod'])
plt.suptitle("3.Senior Citizens mostly prefer Electronic Checques over Credit Card, Bank Transfer\n and hardly use Mailed Check for Payment",fontsize=16)
plt.title("Payment Methods used by Senior Citizens",fontweight="bold",fontsize="18")
plt.xlabel("Payment Methods",fontsize="14")
plt.ylabel("Count",fontsize="14")
plt.show
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>
